# %% [markdown]
# <a href="https://colab.research.google.com/github/BrajanNieto/MISTI/blob/main/Week0_SFSalariesExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If you haven't already, please hit :**
#
# `File` -> `Save a Copy in Drive`
#
# **Copy this notebook to your Google drive, and work on a copy. If you don't do this, your changes won't be saved!**

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.
#
# Follow steps 1-3 [here](https://www.analyticsvidhya.com/blog/2021/06/how-to-load-kaggle-datasets-directly-into-google-colab/) before beginning. This will help you get a bit familiar with Kaggle Datasets.

# %%
! pip install -q kaggle
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json
! kaggle datasets download -d kaggle/sf-salaries
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/cli.py", line 68, in main
#     out = args.func(**command_args)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/kaggle/api/kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
# !unzip sf-salaries.zip
# Out:
# unzip:  cannot find or open sf-salaries.zip, sf-salaries.zip.zip or sf-salaries.zip.ZIP.

# %%
import kagglehub

path = kagglehub.dataset_download("kaggle/sf-salaries")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 11.5M/11.5M [00:01<00:00, 10.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/kaggle/sf-salaries/versions/5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# **Import pandas as pd. Import numpy as np.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv(f"{path}/Salaries.csv")
# Out:
# /tmp/ipython-input-1582820325.py:1: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   sal = pd.read_csv(f"{path}/Salaries.csv")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %% [markdown]
# **Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay?**

# %%
basepay = pd.to_numeric(sal['BasePay'], errors='coerce')

# %%
basepay.mean()
# Out:
# np.float64(66325.4488404877)

# %% [markdown]
# **What is the highest amount of OvertimePay in the dataset ?**

# %%
pd.to_numeric(sal['OvertimePay'], errors='coerce').max()
# Out:
# 245131.88

# %% [markdown]
# **What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll).**

# %%
sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %% [markdown]
# **How much does JOSEPH DRISCOLL make (including benefits)?**

# %%
pd.to_numeric(sal[sal['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits'], errors='coerce')
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %% [markdown]
# **What is the name of highest paid person (including benefits)?**

# %%
sal.loc[pd.to_numeric(sal['TotalPayBenefits'], errors='coerce').idxmax()]['EmployeeName']
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# **What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.loc[pd.to_numeric(sal['TotalPayBenefits'], errors='coerce').idxmin()][['EmployeeName','TotalPayBenefits']]
# Out:
# EmployeeName        Joe Lopez
# TotalPayBenefits      -618.13
# Name: 148653, dtype: object

# %% [markdown]
# **What was the average (mean) BasePay of all employees per year? (2011-2014)?**

# %%
sal.assign(BasePayNum=pd.to_numeric(sal['BasePay'], errors='coerce')).groupby('Year')['BasePayNum'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePayNum, dtype: float64

# %% [markdown]
# **How many unique job titles are there?**

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# **What are the top 5 most common jobs?**

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %% [markdown]
# **How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?)**

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# **How many people have the word Chief in their job title? (This is pretty tricky)**

# %%
sal['JobTitle'].str.contains('Chief', case=False, na=False).sum()
# Out:
# np.int64(627)

# %% [markdown]
# **Bonus: Is there a correlation between length of the Job Title string and Salary?**

# %%
sal['JobTitle'].str.len().corr(pd.to_numeric(sal['TotalPayBenefits'], errors='coerce'))
# Out:
# np.float64(-0.036878445932606675)

# %% [markdown]
# There is a very weak negative correlation (≈ -0.04) between job title length and total compensation, indicating no meaningful relationship between both variables

# %% [markdown]
# # Great Job!
